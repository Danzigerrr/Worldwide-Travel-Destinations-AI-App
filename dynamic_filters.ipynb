# %% [markdown]
# # Dynamic filters

# %% [markdown]
# ## Import Packages

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import mutual_info_classif
import numpy as np

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv("./data/TravelDataset.csv")

# %%
df.head()
# Out:
#                                      id            city    country  \
# 0  c54acf38-3029-496b-8c7a-8343ad82785c           Milan      Italy
# 1  0bd12654-ed64-424e-a044-7bc574bcf078  Yasawa Islands       Fiji
# 2  73036cda-9134-46fc-a2c6-807782d59dfb        Whistler     Canada
# 3  3872c9c0-6b6e-49e1-9743-f46bfe591b86      Guanajuato     Mexico
# 4  e1ebc1b6-8798-422d-847a-22016faff3fd        Surabaya  Indonesia
#
#           region                                  short_description  \
# 0         europe  Chic streets lined with fashion boutiques, his...
# 1        oceania  Crystal-clear waters, secluded beaches, and vi...
# 2  north_america  Snow-capped peaks and lush forests create a se...
# 3  north_america  Winding cobblestone streets and colorful facad...
# 4           asia  Bustling streets filled with the aroma of loca...
#
#     latitude   longitude                                   avg_temp_monthly  \
# 0  45.464194    9.189635  {"1":{"avg":3.7,"max":7.8,"min":0.4},"2":{"avg...
# 1 -17.290947  177.125786  {"1":{"avg":28,"max":30.8,"min":25.8},"2":{"av...
# 2  50.117190 -122.954302  {"1":{"avg":-2.5,"max":0.4,"min":-5.5},"2":{"a...
# 3  20.987700 -101.000000  {"1":{"avg":15.5,"max":22.8,"min":8.7},"2":{"a...
# 4  -7.245972  112.737827  {"1":{"avg":28.1,"max":32.5,"min":25.5},"2":{"...
#
#                        ideal_durations budget_level  culture  adventure  \
# 0            ["Short trip","One week"]       Luxury        5          2
# 1             ["Long trip","One week"]       Luxury        2          4
# 2  ["Short trip","Weekend","One week"]       Luxury        3          5
# 3  ["Weekend","One week","Short trip"]    Mid-range        5          3
# 4             ["Short trip","Weekend"]       Budget        4          3
#
#    nature  beaches  nightlife  cuisine  wellness  urban  seclusion
# 0       2        1          4        5         3      5          2
# 1       5        5          2        3         4      1          5
# 2       5        2          3        3         4      2          4
# 3       3        1          3        4         3      4          2
# 4       3        2          3        4         3      4          2

# %%
# Convert 'ideal_durations' to individual one-hot encoded columns
df["ideal_durations"] = df["ideal_durations"].apply(eval)  # if it's stored as a string
duration_ohe = df["ideal_durations"].explode().str.get_dummies().groupby(level=0).max()
df = df.join(duration_ohe).drop(columns=["ideal_durations"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 560 entries, 0 to 559
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 560 non-null    object
#  1   city               560 non-null    object
#  2   country            560 non-null    object
#  3   region             560 non-null    object
#  4   short_description  560 non-null    object
#  5   latitude           560 non-null    float64
#  6   longitude          560 non-null    float64
#  7   avg_temp_monthly   560 non-null    object
#  8   budget_level       560 non-null    object
#  9   culture            560 non-null    int64
#  10  adventure          560 non-null    int64
#  11  nature             560 non-null    int64
#  12  beaches            560 non-null    int64
#  13  nightlife          560 non-null    int64
#  14  cuisine            560 non-null    int64
#  15  wellness           560 non-null    int64
#  16  urban              560 non-null    int64
#  17  seclusion          560 non-null    int64
#  18  Day trip           560 non-null    int64
#  19  Long trip          560 non-null    int64
#  20  One week           560 non-null    int64
#  21  Short trip         560 non-null    int64
#  22  Weekend            560 non-null    int64
# dtypes: float64(2), int64(14), object(7)
# memory usage: 100.8+ KB

# %%
df.describe()
# Out:
#          latitude   longitude    culture   adventure      nature     beaches  \
# count  560.000000  560.000000  560.00000  560.000000  560.000000  560.000000
# mean    22.502186    7.914665    3.85000    3.178571    3.728571    2.380357
# std     27.980022   78.813803    0.81291    0.798190    0.903920    1.435547
# min    -54.807306 -175.201808    2.00000    2.000000    2.000000    1.000000
# 25%      5.268054  -64.439118    3.00000    3.000000    3.000000    1.000000
# 50%     31.793618   10.711854    4.00000    3.000000    4.000000    2.000000
# 75%     43.673199   50.020162    4.00000    4.000000    4.000000    3.000000
# max     78.719852  179.332896    5.00000    5.000000    5.000000    5.000000
#
#         nightlife     cuisine    wellness       urban   seclusion    Day trip  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean     3.019643    3.792857    3.073214    3.146429    3.028571    0.035714
# std      0.921599    0.679329    0.592134    1.018604    0.989699    0.185743
# min      1.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 25%      2.000000    3.000000    3.000000    2.000000    2.000000    0.000000
# 50%      3.000000    4.000000    3.000000    3.000000    3.000000    0.000000
# 75%      4.000000    4.000000    3.000000    4.000000    4.000000    0.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    1.000000
#
#         Long trip    One week  Short trip     Weekend
# count  560.000000  560.000000  560.000000  560.000000
# mean     0.094643    0.719643    0.955357    0.751786
# std      0.292983    0.449575    0.206703    0.432363
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000
# 50%      0.000000    1.000000    1.000000    1.000000
# 75%      0.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000

# %% [markdown]
# # Generate Dynamic Filters

# %% [markdown]
# ## Get Top Informative Features

# %%
# Simulate selecting a subset of destinations
df["label"] = 0
df.loc[df.sample(frac=0.8).index, "label"] = 1  # simulate "visible" destinations

# %%
df.describe()
# Out:
#          latitude   longitude    culture   adventure      nature     beaches  \
# count  560.000000  560.000000  560.00000  560.000000  560.000000  560.000000
# mean    22.502186    7.914665    3.85000    3.178571    3.728571    2.380357
# std     27.980022   78.813803    0.81291    0.798190    0.903920    1.435547
# min    -54.807306 -175.201808    2.00000    2.000000    2.000000    1.000000
# 25%      5.268054  -64.439118    3.00000    3.000000    3.000000    1.000000
# 50%     31.793618   10.711854    4.00000    3.000000    4.000000    2.000000
# 75%     43.673199   50.020162    4.00000    4.000000    4.000000    3.000000
# max     78.719852  179.332896    5.00000    5.000000    5.000000    5.000000
#
#         nightlife     cuisine    wellness       urban   seclusion    Day trip  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean     3.019643    3.792857    3.073214    3.146429    3.028571    0.035714
# std      0.921599    0.679329    0.592134    1.018604    0.989699    0.185743
# min      1.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 25%      2.000000    3.000000    3.000000    2.000000    2.000000    0.000000
# 50%      3.000000    4.000000    3.000000    3.000000    3.000000    0.000000
# 75%      4.000000    4.000000    3.000000    4.000000    4.000000    0.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    1.000000
#
#         Long trip    One week  Short trip     Weekend       label
# count  560.000000  560.000000  560.000000  560.000000  560.000000
# mean     0.094643    0.719643    0.955357    0.751786    0.800000
# std      0.292983    0.449575    0.206703    0.432363    0.400358
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    1.000000
# 50%      0.000000    1.000000    1.000000    1.000000    1.000000
# 75%      0.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
selected_destinations = df[df["label"]==1]
selected_destinations
# Out:
#                                        id            city         country  \
# 0    c54acf38-3029-496b-8c7a-8343ad82785c           Milan           Italy
# 1    0bd12654-ed64-424e-a044-7bc574bcf078  Yasawa Islands            Fiji
# 3    3872c9c0-6b6e-49e1-9743-f46bfe591b86      Guanajuato          Mexico
# 4    e1ebc1b6-8798-422d-847a-22016faff3fd        Surabaya       Indonesia
# 6    20f80ed8-ce7f-43ad-a34d-a0cb156f5d4e        Windhoek         Namibia
# ..                                    ...             ...             ...
# 554  f38b9348-e581-4de5-bafa-1efb5c28e458          Nelson     New Zealand
# 555  778d28df-a4fa-4328-896e-4a9f80216fda            Maun        Botswana
# 557  8c8c7203-2a45-44ba-9fb2-b5158104375e      Manchester  United Kingdom
# 558  ba72b976-10f9-4415-a818-32cf17d8e649      Copenhagen         Denmark
# 559  62caf451-c399-4d64-a770-1efd93a603ef           Sucre         Bolivia
#
#             region                                  short_description  \
# 0           europe  Chic streets lined with fashion boutiques, his...
# 1          oceania  Crystal-clear waters, secluded beaches, and vi...
# 3    north_america  Winding cobblestone streets and colorful facad...
# 4             asia  Bustling streets filled with the aroma of loca...
# 6           africa  A blend of modernity and tradition, with bustl...
# ..             ...                                                ...
# 554        oceania  Sun-drenched coastal charm with vibrant market...
# 555         africa  A gateway to the Okavango Delta, offering a se...
# 557         europe  Industrial heritage meets modern creativity, w...
# 558         europe  Charming canals, vibrant neighborhoods, and a ...
# 559  south_america  Whitewashed colonial buildings, vibrant plazas...
#
#       latitude   longitude                                   avg_temp_monthly  \
# 0    45.464194    9.189635  {"1":{"avg":3.7,"max":7.8,"min":0.4},"2":{"avg...
# 1   -17.290947  177.125786  {"1":{"avg":28,"max":30.8,"min":25.8},"2":{"av...
# 3    20.987700 -101.000000  {"1":{"avg":15.5,"max":22.8,"min":8.7},"2":{"a...
# 4    -7.245972  112.737827  {"1":{"avg":28.1,"max":32.5,"min":25.5},"2":{"...
# 6   -22.533560   17.045478  {"1":{"avg":23.9,"max":32.3,"min":17.8},"2":{"...
# ..         ...         ...                                                ...
# 554 -41.271085  173.283676  {"1":{"avg":18.6,"max":22,"min":14.8},"2":{"av...
# 555 -19.986095   23.422435  {"1":{"avg":26.6,"max":32,"min":21.2},"2":{"av...
# 557  53.479489   -2.245115  {"1":{"avg":4.7,"max":7.1,"min":2},"2":{"avg":...
# 558  55.686724   12.570072  {"1":{"avg":2.6,"max":4.2,"min":0.6},"2":{"avg...
# 559 -19.047725  -65.259431  {"1":{"avg":15.4,"max":19.8,"min":10.2},"2":{"...
#
#     budget_level  culture  ...  cuisine  wellness  urban  seclusion  Day trip  \
# 0         Luxury        5  ...        5         3      5          2         0
# 1         Luxury        2  ...        3         4      1          5         0
# 3      Mid-range        5  ...        4         3      4          2         0
# 4         Budget        4  ...        4         3      4          2         0
# 6      Mid-range        3  ...        3         3      3          4         0
# ..           ...      ...  ...      ...       ...    ...        ...       ...
# 554    Mid-range        3  ...        3         3      3          4         0
# 555    Mid-range        3  ...        3         3      2          4         0
# 557    Mid-range        4  ...        4         3      4          2         0
# 558    Mid-range        5  ...        4         3      5          2         0
# 559       Budget        4  ...        3         2      2          4         0
#
#      Long trip  One week  Short trip  Weekend  label
# 0            0         1           1        0      1
# 1            1         1           0        0      1
# 3            0         1           1        1      1
# 4            0         0           1        1      1
# 6            0         1           1        1      1
# ..         ...       ...         ...      ...    ...
# 554          0         1           1        0      1
# 555          0         1           1        0      1
# 557          0         1           1        1      1
# 558          0         1           1        1      1
# 559          0         1           1        1      1
#
# [448 rows x 24 columns]

# %%
def get_dynamic_filters(dataframe, top_n=5):
    df = dataframe.copy()
        
    # Convert categorical columns
    le_budget = LabelEncoder()
    le_region = LabelEncoder()
    le_country = LabelEncoder()
    le_city = LabelEncoder()
    df["budget_level_enc"] = le_budget.fit_transform(df["budget_level"])
    df["region_enc"] = le_region.fit_transform(df["region"])
    df["country_enc"] = le_country.fit_transform(df["country"])
    df["city_enc"] = le_city.fit_transform(df["city"])
    
    # use these features to analyse information gain  
    feature_cols = [
        "Day trip", "Long trip", "Short trip", "One week", "Weekend",
        "culture", "adventure", "nature", "beaches", "nightlife", "cuisine", "wellness", "urban", "seclusion", 
        "region_enc", "country_enc", "city_enc", "budget_level_enc"
    ]

    X = df[feature_cols]
    y = df["label"]

    # Compute mutual information (entropy-based score)
    info_gains = mutual_info_classif(X, y, discrete_features='auto')


    gain_df = pd.DataFrame({
        "feature": feature_cols,
        "info_gain": info_gains
    }).sort_values(by="info_gain", ascending=False)

    
    # Filter to rows where label == 1
    selected = df[df["label"] == 1]
    
    # Add column with unique values from rows where label == 1
    gain_df["unique_values_label_1"] = gain_df["feature"].apply(lambda col: selected[col].unique())

    # Sort and return
    gain_df = gain_df.sort_values(by="info_gain", ascending=False)
    return gain_df.head(top_n)

# %%
top_filters = get_dynamic_filters(selected_destinations,5)
print(top_filters)
# Out:
#       feature     info_gain unique_values_label_1
# 3    One week  2.232143e-03                [1, 0]
# 2  Short trip  1.116071e-03                [1, 0]
# 1   Long trip  3.330669e-16                [0, 1]
# 0    Day trip  3.330669e-16                [0, 1]
# 4     Weekend  3.330669e-16                [0, 1]

# %% [markdown]
# ## Generate Filters
